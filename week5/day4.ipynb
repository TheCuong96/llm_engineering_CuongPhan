# %% [markdown]
# # Ngày 4 về RAG
#
# ## Đánh giá!
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Hãy luôn cân nhắc cách bạn sẽ đánh giá RAG cho doanh nghiệp của mình</h2>
#             <span style="color:#181;">Đây là một phần cực kỳ quan trọng khi xây dựng pipeline RAG chính xác và đáng tin cậy. Điều này cũng áp dụng cho nhiều khía cạnh của việc giải quyết các bài toán kinh doanh bằng LLM. Mọi người thường tập trung vào kiến trúc RAG và các framework RAG cho doanh nghiệp của mình. Nhưng điều còn quan trọng hơn nữa chính là việc đánh giá!</span>
#         </td>
#     </tr>
# </table>

# %%
from evaluation import test

# %%
tests = test.load_tests()

# %%
len(tests)
# Out:
# 150

# %%
example = tests[0]
print(example.question)
print(example.category)
print(example.reference_answer)
print(example.keywords)
# Out:
# Ai đã giành giải IIOTY danh giá vào năm 2023?
# direct_fact
# Maxine Thompson đã giành giải Nhà đổi mới của năm tại Insurellm (IIOTY) danh giá vào năm 2023.
# ['Maxine', 'Thompson', 'IIOTY']

# %%
from collections import Counter
count = Counter([t.category for t in tests])
count
# Out:
# Counter({'direct_fact': 70,
#          'temporal': 20,
#          'spanning': 20,
#          'comparative': 10,
#          'numerical': 10,
#          'relationship': 10,
#          'holistic': 10})

# %%
from evaluation.eval import evaluate_retrieval, evaluate_answer

# %%
evaluate_retrieval(example)
# Out:
# RetrievalEval(mrr=0.16666666666666666, ndcg=0.28711770538226206, keywords_found=2, total_keywords=3, keyword_coverage=66.66666666666666)

# %%
eval, answer, chunks = evaluate_answer(example)

# %%
eval
# Out:
# AnswerEval(feedback="Câu trả lời xác định chính xác Maxine là người chiến thắng và đề cập đến giải IIOTY năm 2023, nhưng lại bỏ sót họ tên đầy đủ Thompson có trong câu trả lời tham chiếu. Điều này ảnh hưởng đến tính đầy đủ. Mức độ liên quan cao vì câu trả lời trực tiếp giải đáp câu hỏi về người giành giải.", accuracy=5.0, completeness=4.0, relevance=5.0)

# %%
print(eval.feedback)
print(eval.accuracy)
print(eval.completeness)
print(eval.relevance)
# Out:
# Câu trả lời xác định chính xác Maxine là người chiến thắng và đề cập đến giải IIOTY năm 2023, nhưng lại bỏ sót họ tên đầy đủ Thompson có trong câu trả lời tham chiếu. Điều này ảnh hưởng đến tính đầy đủ. Mức độ liên quan cao vì câu trả lời trực tiếp giải đáp câu hỏi về người giành giải.
# 5.0
# 4.0
# 5.0
