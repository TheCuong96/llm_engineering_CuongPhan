# %% [markdown]
# # Ngày 4 về RAG
#
# ## Đánh giá!
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Hãy luôn cân nhắc cách bạn sẽ đánh giá RAG cho doanh nghiệp của mình</h2>
#             <span style="color:#181;">Đây là một phần cực kỳ quan trọng khi xây dựng pipeline RAG chính xác và đáng tin cậy. Điều này cũng áp dụng cho nhiều khía cạnh của việc giải quyết các bài toán kinh doanh bằng LLM. Mọi người thường tập trung vào kiến trúc RAG và các framework RAG cho doanh nghiệp của mình. Nhưng điều còn quan trọng hơn nữa chính là việc đánh giá!</span>
#         </td>
#     </tr>
# </table>

# %%
from evaluation import test  # Nhập test từ gói evaluation.

# %%
tests = test.load_tests()  # Nạp toàn bộ bộ ca kiểm thử đánh giá.

# %%
len(tests)  # Hiển thị tổng số ca kiểm thử đã nạp.
# Out:
# 150

# %%
example = tests[0]  # Chọn ca kiểm thử đầu tiên làm ví dụ.
print(example.question)  # In giá trị hoặc thông báo này ra phần output của ô.
print(example.category)  # In giá trị hoặc thông báo này ra phần output của ô.
print(example.reference_answer)  # In giá trị hoặc thông báo này ra phần output của ô.
print(example.keywords)  # In giá trị hoặc thông báo này ra phần output của ô.
# Out:
# Who won the prestigious IIOTY award in 2023?
# direct_fact
# Maxine Thompson won the prestigious Insurellm Innovator of the Year (IIOTY) award in 2023.
# ['Maxine', 'Thompson', 'IIOTY']

# %%
from collections import Counter  # Nhập Counter từ gói collections.
count = Counter([t.category for t in tests])  # Đếm số phần tử hiện có trong collection.
count  # Hiển thị giá trị này trong output của notebook.
# Out:
# Counter({'direct_fact': 70,
#          'temporal': 20,
#          'spanning': 20,
#          'comparative': 10,
#          'numerical': 10,
#          'relationship': 10,
#          'holistic': 10})

# %%
from evaluation.eval import evaluate_retrieval, evaluate_answer  # Nhập evaluate_retrieval, evaluate_answer từ gói evaluation.eval.

# %%
evaluate_retrieval(example)  # Chấm chất lượng truy xuất cho ca kiểm thử mẫu và hiển thị các chỉ số.
# Out:
# RetrievalEval(mrr=0.6666666666666666, ndcg=0.5561086263536886, keywords_found=2, total_keywords=3, keyword_coverage=66.66666666666666)

# %%
eval, answer, chunks = evaluate_answer(example)  # Đánh giá câu trả lời mẫu và tách điểm số, câu trả lời cùng các đoạn đã truy xuất.

# %%
eval  # Hiển thị giá trị này trong output của notebook.
# Out:
# AnswerEval(feedback="The answer correctly identifies Maxine from Insurellm as the winner of the IIOTY award in 2023, aligning with the reference answer. However, it introduces a slight variation in the name, calling her 'Maxine' instead of 'Maxine Thompson,' which could cause some ambiguity. The answer does not specify the award title, 'Insurellm Innovator of the Year (IIOTY),' explicitly, but the phrase 'IIOTY Innovator Award' implies the same. Overall, the key information is present and accurate, but slight clarification on the full name and award title would improve completeness.", accuracy=5.0, completeness=4.0, relevance=5.0)

# %%
print(eval.feedback)  # In giá trị hoặc thông báo này ra phần output của ô.
print(eval.accuracy)  # In giá trị hoặc thông báo này ra phần output của ô.
print(eval.completeness)  # In giá trị hoặc thông báo này ra phần output của ô.
print(eval.relevance)  # In giá trị hoặc thông báo này ra phần output của ô.
# Out:
# The answer correctly identifies Maxine from Insurellm as the winner of the IIOTY award in 2023, aligning with the reference answer. However, it introduces a slight variation in the name, calling her 'Maxine' instead of 'Maxine Thompson,' which could cause some ambiguity. The answer does not specify the award title, 'Insurellm Innovator of the Year (IIOTY),' explicitly, but the phrase 'IIOTY Innovator Award' implies the same. Overall, the key information is present and accurate, but slight clarification on the full name and award title would improve completeness.
# 5.0
# 4.0
# 5.0
