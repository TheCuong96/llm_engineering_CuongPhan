# %% [markdown]
# # Bài tập cuối tuần 1
#
# Để thể hiện bạn đã quen với OpenAI API, và cả Ollama, hãy xây một tool (công cụ) nhận một câu hỏi kỹ thuật,
# rồi trả lời bằng một explanation (lời giải thích). Đây là tool bạn sẽ tự dùng được trong suốt khóa học!

# %%
# imports (nhập thư viện)

# %%
# constants (hằng số)

MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2'

# %%
# set up environment (thiết lập môi trường)

# %%
# đây là question (câu hỏi); gõ đè lên để hỏi thứ khác

question = """
Hãy giải thích code này làm gì và vì sao:
yield from {book.get("author") for book in books if book.get("author")}
"""

# %%
# Gọi gpt-4o-mini để trả lời, có streaming (luồng chảy)

# %%
# Gọi Llama 3.2 để trả lời
