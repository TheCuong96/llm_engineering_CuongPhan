# %% [markdown]
# # Giới thiệu Colab
#
# Tìm hiểu Google Colab và tạo tài khoản Google (nếu chưa có) [tại đây](https://colab.research.google.com/)
#
# Bạn có thể dùng free tier (bậc miễn phí) hoặc chi phí rất nhỏ để hoàn thành tất cả project trong khóa học. Bản thân mình đã đăng ký Colab Pro+ và rất thích — nhưng không bắt buộc.
#
# Để xem Colab làm được gì, hãy mở liên kết bên dưới!
#
# https://colab.research.google.com/drive/1DjcrYDZldAXKJ08x1uYIVCtItoLPk1Wr?usp=sharing

# %% [markdown]
# https://colab.research.google.com/drive/1jUGAM3E5PgybXwUdsN6y9W2ab8PrTlb-?authuser=6#scrollTo=qw_WV7SgTWBv
