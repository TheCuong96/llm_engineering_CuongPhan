# %% [markdown]
# # Tokenizers
#
# Mình mời bạn quay lại Google Colab tuyệt vời, nơi chúng ta sẽ xem các Tokenizer (bộ tách token) khác nhau:
#
# https://colab.research.google.com/drive/1WD6Y2N7ctQi1X9wa6rpkg8UfyA4iSVuz?usp=sharing

# %%
https://colab.research.google.com/drive/1ajC3Q38V_t8aXg0K3Tl5HetxGgt5bpzg?usp=sharing

# %%
https://colab.research.google.com/drive/1xlpsWaAtVMZ7XxcJFnKi5MHJefzgSPrg?usp=sharing
