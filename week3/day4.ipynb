# %% [markdown]
# # Models
#
# Bây giờ — Colab này hé lộ trái tim (hay bộ não?) của thư viện transformers: các model (mô hình).
#
# https://colab.research.google.com/drive/1hhR9Z-yiqjUe7pJjVQw4c74z_V3VchLy?usp=sharing
#
# Notebook này chạy tốt trên GPU T4 chi phí thấp hoặc miễn phí.

# %% [markdown]
# https://colab.research.google.com/drive/1axYmejCWVsiuizdgvaSVy7UKblC2ySYo?usp=sharing
